# %%
import numpy as np

# %%
n = 3

# %%
2 ** 3
# Out:
# 8

# %%
120
# Out:
# 120

# %%
2 ** 7
# Out:
# 128

# %%
2 ** 32
# Out:
# 4294967296

# %%
x = 5

# %%
np.int8
# Out:
# numpy.int8

# %% [markdown]
# ![numpy](https://github.com/ine-rmotr-curriculum/freecodecamp-intro-to-numpy/blob/master/numpy.png?raw=1)
